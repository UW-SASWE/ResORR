# %%
# %load_ext autoreload
# %autoreload 2
from rat import run_rat

# %%
config_path = '../params/rat_config.yaml'
run_rat.run_rat(config_path)

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/colorado/basins/gunnison/final_outputs/dels/Blue_Mesa.csv', parse_dates=['date']).set_index('date')
df.plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df = pd.read_csv('../data/colorado/basins/gunnison/final_outputs/sarea/Blue_Mesa.csv', parse_dates=['date']).set_index('date')
import matplotlib.pyplot as plt
df.plot(marker='.')
plt.title('Blue Mesa Surface Area')
# Out:
# Text(0.5, 1.0, 'Blue Mesa Surface Area')

# %%
df = pd.read_csv('../data/colorado/basins/gunnison/final_outputs/outflow/Blue_Mesa.csv', parse_dates=['date']).set_index('date')
import matplotlib.pyplot as plt
df.plot(marker='.')
plt.title('Blue Mesa Outflow')
# Out:
# Text(0.5, 1.0, 'Blue Mesa Outflow')
